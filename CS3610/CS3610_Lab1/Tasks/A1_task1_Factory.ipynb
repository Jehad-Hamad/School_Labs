# %%
import sys
import os
sys.path.append(os.path.abspath(".."))

from FactoryZoo.TorontoZooClass import TorontoZoo
from FactoryZoo.CalgaryZooClass import CalgaryZoo

t_Zoo = TorontoZoo()
t_Zoo.startVist()
print("===================")
c_Zoo = CalgaryZoo()
c_Zoo.startVist()
# Out:
# Welcome to the Toronto Zoo! Our Itinerary: 1) African Savanna. 2) Tundra Trek
# The Lion is Roaring
# The Elephant is trumpeting
# The Penguin is honking
# The White bear is roaring in the snow
# ...
# Welcome to the Calgary Zoo! Our Itinerary: 1) Penguin Plunge. 2)  Wild Canad
# The Moose is neighing
# The Penguin is honking
# The Grizzly bear is roaring in the forest
